# %% [markdown]
# <a href="https://colab.research.google.com/github/ghyunjin25/Colab/blob/main/GANcode(42m0s).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

import numpy as np

# for MNIST data
import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image
from torch.autograd import Variable


import matplotlib.pyplot as plt

# %%
# download the MINST data

batch_size = 64

transforms_train = transforms.Compose([
    transforms.Resize(28),
    transforms.ToTensor(), # data를 pytorch의 tensor형식으로 바꿉니다
    transforms.Normalize([0.5], [0.5]) # 픽셀값을 0 ~ 1에서 -1 ~ 1 로 바꿔줍니다.
])

train_dataset = datasets.MNIST(root="./dataset", train=True, download=True, transform=transforms_train)

# data를 batch size만큼만 가져오는 dataloader를 만듭니다.
dataloader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle=True, num_workers=4)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 446kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.12MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 4.93MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
images, labels = next(iter(dataloader))
img = torchvision.utils.make_grid(images)

img = img.numpy().transpose(1,2,0)
std = [0.5,0.5,0.5]
mean = [0.5,0.5,0.5]
img = img*std+mean
print([labels[i] for i in range(64)])
plt.imshow(img)
# Out:
# [tensor(8), tensor(2), tensor(3), tensor(7), tensor(5), tensor(3), tensor(5), tensor(2), tensor(3), tensor(3), tensor(1), tensor(8), tensor(2), tensor(8), tensor(6), tensor(3), tensor(0), tensor(3), tensor(2), tensor(6), tensor(8), tensor(4), tensor(3), tensor(9), tensor(2), tensor(6), tensor(3), tensor(3), tensor(0), tensor(5), tensor(2), tensor(3), tensor(9), tensor(4), tensor(8), tensor(5), tensor(9), tensor(8), tensor(8), tensor(2), tensor(3), tensor(0), tensor(0), tensor(7), tensor(3), tensor(8), tensor(4), tensor(0), tensor(1), tensor(2), tensor(5), tensor(3), tensor(5), tensor(7), tensor(8), tensor(1), tensor(1), tensor(5), tensor(1), tensor(4), tensor(1), tensor(9), tensor(6), tensor(8)]

# %%
# image

channels = 1
img_size = 28

img_shape = (channels, img_size, img_size)

# %%
# dimensionality of the latent space
# latent vector를 추출하기 위한 noise 분포의 dimension (정규분포를 따름)
latent_dim = 100

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        def block(input_dim, output_dim, normalize=True):
            layers = [nn.Linear(input_dim, output_dim)]
            if normalize:
                layers.append(nn.BatchNorm1d(output_dim, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        # generater의 model은 여러개의 block을 쌓아서 만들어짐
        self.model = nn.Sequential(
            *block(latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh()
        )

    def forward(self, z):
        # z : input noise vector
        img = self.model(z)
        img = img.view(img.size(0), *img_shape)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(int(np.prod(img_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)

        return validity

# %%
''' Hyper parameter '''
# learning rate
lr = 0.0002

# decay of first order momentum of gradient
b1 = 0.5
b2 = 0.999


# Initialize generator and discriminator
generator = Generator()
discriminator = Discriminator()

# Loss function
adversarial_loss = nn.BCELoss()

# Adam Optimizer
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

# %%
# GPU
cuda = True if torch.cuda.is_available() else False

if cuda :
  generator.cuda()
  discriminator.cuda()
  adversarial_loss.cuda()

# %%
import time

# number of epochs of training
n_epochs = 200

# interval between image samples
sample_interval = 2000

start_time = time.time()

Tensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor


for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(dataloader):

        # Adversarial ground truths
        ## 실제 이미지는 1로, 가짜 이미지는 0으로 label됩니다.
        real = Variable(Tensor(imgs.size(0), 1).fill_(1.0), requires_grad=False)
        fake = Variable(Tensor(imgs.size(0), 1).fill_(0.0), requires_grad=False)

        # Configure input
        real_imgs = Variable(imgs.type(Tensor))

        # -----------------
        #  Train Generator
        # -----------------

        optimizer_G.zero_grad()

        # Sample noise as generator input
        z = Variable(Tensor(np.random.normal(0, 1, (imgs.shape[0], latent_dim))))

        # Generate a batch of images
        ## random sampling한 값인 z를 생성자에 넣어 이미지를 생성합니다.
        generated_imgs = generator(z)

        # Loss measures generator's ability to fool the discriminator
        ## 생성된 이미지를 discriminator가 판별하게 한 후, loss값을 계산합니다.
        g_loss = adversarial_loss(discriminator(generated_imgs), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------

        optimizer_D.zero_grad()

        # Measure discriminator's ability to classify real from generated samples
        ## 실제 이미지는 real(1)로, 가짜 이미지는 fake(0)으로 판별하도록 계산합니다.
        real_loss = adversarial_loss(discriminator(real_imgs), real)
        fake_loss = adversarial_loss(discriminator(generated_imgs.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(dataloader) + i
        if done % sample_interval == 0:
            # 생성된 이미지 중에서 25개만 선택하여 5 X 5 격자 이미지에 출력
            save_image(generated_imgs.data[:25], f"data{epoch}.png", nrow=5, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/200] [D loss: 0.452366] [G loss: 1.383607] [Elapsed time: 46.67s]
# [Epoch 1/200] [D loss: 0.311048] [G loss: 2.204444] [Elapsed time: 92.43s]
# [Epoch 2/200] [D loss: 0.229596] [G loss: 3.033231] [Elapsed time: 139.43s]
# [Epoch 3/200] [D loss: 0.220298] [G loss: 1.562816] [Elapsed time: 185.10s]
# [Epoch 4/200] [D loss: 0.118035] [G loss: 1.899108] [Elapsed time: 231.73s]
# [Epoch 5/200] [D loss: 0.318612] [G loss: 3.466965] [Elapsed time: 277.41s]
# [Epoch 6/200] [D loss: 0.263430] [G loss: 2.094339] [Elapsed time: 325.54s]
# [Epoch 7/200] [D loss: 0.207664] [G loss: 1.388741] [Elapsed time: 374.71s]
# [Epoch 8/200] [D loss: 0.302560] [G loss: 0.976094] [Elapsed time: 421.34s]
# [Epoch 9/200] [D loss: 0.497868] [G loss: 4.428854] [Elapsed time: 469.05s]
# [Epoch 10/200] [D loss: 0.126554] [G loss: 3.694761] [Elapsed time: 516.81s]
# [Epoch 11/200] [D loss: 0.158917] [G loss: 2.245146] [Elapsed time: 563.61s]
# [Epoch 12/200] [D loss: 0.187150] [G loss: 2.386338] [Elapsed time: 611.33s]
# [Epoch 13/200] [D loss: 0.240734] [G loss: 2.933807] [Elapsed time: 660.08s]
# [Epoch 14/200] [D loss: 0.145678] [G loss: 2.677146] [Elapsed time: 706.75s]
# [Epoch 15/200] [D loss: 0.098970] [G loss: 3.191010] [Elapsed time: 754.46s]
# [Epoch 16/200] [D loss: 0.115271] [G loss: 3.398635] [Elapsed time: 802.24s]
# [Epoch 17/200] [D loss: 0.116919] [G loss: 1.853634] [Elapsed time: 848.91s]
# [Epoch 18/200] [D loss: 0.102936] [G loss: 3.987537] [Elapsed time: 896.73s]
# [Epoch 19/200] [D loss: 0.110366] [G loss: 3.362498] [Elapsed time: 947.60s]
# [Epoch 20/200] [D loss: 0.057563] [G loss: 2.876532] [Elapsed time: 994.74s]
# [Epoch 21/200] [D loss: 0.114512] [G loss: 3.301447] [Elapsed time: 1041.97s]
# [Epoch 22/200] [D loss: 0.270920] [G loss: 2.297309] [Elapsed time: 1089.61s]
# [Epoch 23/200] [D loss: 0.189011] [G loss: 2.577465] [Elapsed time: 1136.93s]
# [Epoch 24/200] [D loss: 0.126679] [G loss: 3.305100] [Elapsed time: 1184.11s]
# [Epoch 25/200] [D loss: 0.121199] [G loss: 2.860918] [Elapsed time: 1231.96s]
# [Epoch 26/200] [D loss: 0.172769] [G loss: 2.651562] [Elapsed time: 1280.66s]
# [Epoch 27/200] [D loss: 0.417286] [G loss: 0.831129] [Elapsed time: 1328.16s]
# [Epoch 28/200] [D loss: 0.156768] [G loss: 2.919299] [Elapsed time: 1376.32s]
# [Epoch 29/200] [D loss: 0.194353] [G loss: 2.514887] [Elapsed time: 1424.13s]
# [Epoch 30/200] [D loss: 0.160120] [G loss: 3.443271] [Elapsed time: 1471.31s]
# [Epoch 31/200] [D loss: 0.160357] [G loss: 2.057923] [Elapsed time: 1519.30s]
# [Epoch 32/200] [D loss: 0.304626] [G loss: 3.016806] [Elapsed time: 1568.51s]
# [Epoch 33/200] [D loss: 0.191610] [G loss: 3.203427] [Elapsed time: 1615.47s]
# [Epoch 34/200] [D loss: 0.334818] [G loss: 3.310627] [Elapsed time: 1663.51s]
# [Epoch 35/200] [D loss: 0.173723] [G loss: 2.348138] [Elapsed time: 1711.37s]
# [Epoch 36/200] [D loss: 0.308027] [G loss: 3.250781] [Elapsed time: 1758.36s]
# [Epoch 37/200] [D loss: 0.139056] [G loss: 2.702425] [Elapsed time: 1806.33s]
# [Epoch 38/200] [D loss: 0.128897] [G loss: 2.805506] [Elapsed time: 1854.33s]
# [Epoch 39/200] [D loss: 0.218405] [G loss: 1.593978] [Elapsed time: 1902.56s]
# [Epoch 40/200] [D loss: 0.101019] [G loss: 2.392362] [Elapsed time: 1950.52s]
# [Epoch 41/200] [D loss: 0.279095] [G loss: 1.988680] [Elapsed time: 1998.29s]
# [Epoch 42/200] [D loss: 0.276043] [G loss: 2.493080] [Elapsed time: 2045.45s]
# [Epoch 43/200] [D loss: 0.285026] [G loss: 1.716230] [Elapsed time: 2093.67s]
# [Epoch 44/200] [D loss: 0.200851] [G loss: 1.805952] [Elapsed time: 2141.64s]
# [Epoch 45/200] [D loss: 0.200282] [G loss: 2.962864] [Elapsed time: 2189.71s]
# [Epoch 46/200] [D loss: 0.311516] [G loss: 1.867617] [Elapsed time: 2237.55s]
# [Epoch 47/200] [D loss: 0.379453] [G loss: 0.993538] [Elapsed time: 2285.57s]
# [Epoch 48/200] [D loss: 0.280004] [G loss: 2.350226] [Elapsed time: 2332.55s]
# [Epoch 49/200] [D loss: 0.477626] [G loss: 0.742019] [Elapsed time: 2380.55s]
# [Epoch 50/200] [D loss: 0.331375] [G loss: 1.811180] [Elapsed time: 2428.28s]
# [Epoch 51/200] [D loss: 0.173459] [G loss: 2.244877] [Elapsed time: 2475.13s]
# [Epoch 52/200] [D loss: 0.208314] [G loss: 2.569601] [Elapsed time: 2523.98s]
